# %%
# =====================================================================
# TASK1: Strategic Planning and Data Exploration in Logistics

# =====================================================================

import pandas as pd
import numpy as np

# Set reproducibility seed
np.random.seed(42)

print("--- 1. Initializing Logistics Scenario Simulation ---")
# Scenario: Urban Last-Mile E-Commerce Delivery Optimization
n_samples = 1000

logistics_strategy_data = {
    'order_id': range(1000, 1000 + n_samples),
    'distance_km': np.random.uniform(2.0, 35.0, n_samples),
    'traffic_score': np.random.uniform(1.0, 10.0, n_samples),
    'package_weight_kg': np.random.uniform(0.5, 20.0, n_samples),
    'delivery_time_hrs': np.random.uniform(0.5, 4.5, n_samples)
}

df_strategy = pd.DataFrame(logistics_strategy_data)

print(f"Dataset successfully created!")
print(f"Total simulated deliveries: {len(df_strategy)}")
print("\nFirst 5 rows of the simulated dataset:")
display(df_strategy.head()) # display() creates a nice formatted table in Colab

print("\n--- 2. Defining Key Performance Indicators (KPIs) ---")
print("• On-Time Delivery Rate (OTDR) - Target: >95%")
print("• Average Transit Time - Mean duration from dispatch to delivery")
print("• Cost per Kilometer (CPK) - Total expense divided by distance traveled")

print("\n--- 3. Strategic Roadmap Summary ---")
print("Phase 1: Data Collection (GPS & Logistics logs)")
print("Phase 2: Data Cleaning (Handling missing values & outliers)")
print("Phase 3: Exploratory Data Analysis (EDA & correlations)")
print("Phase 4: Predictive Modeling (Random Forest Regressor)")
# Out:
# --- 1. Initializing Logistics Scenario Simulation ---
# Dataset successfully created!
# Total simulated deliveries: 1000
#
# First 5 rows of the simulated dataset:
#    order_id  distance_km  traffic_score  package_weight_kg  delivery_time_hrs
# 0      1000    14.359824       2.666196           5.603261           3.190812
# 1      1001    33.373572       5.877109           5.316087           3.686726
# 2      1002    26.155800       8.856513          18.171964           1.501872
# 3      1003    21.755730       7.590024           5.366151           2.999496
# 4      1004     7.148615       8.259050           5.803020           2.786984
# --- 2. Defining Key Performance Indicators (KPIs) ---
# • On-Time Delivery Rate (OTDR) - Target: >95%
# • Average Transit Time - Mean duration from dispatch to delivery
# • Cost per Kilometer (CPK) - Total expense divided by distance traveled
#
# --- 3. Strategic Roadmap Summary ---
# Phase 1: Data Collection (GPS & Logistics logs)
# ...
